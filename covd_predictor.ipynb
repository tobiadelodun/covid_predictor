# %% [markdown]
# # Final Project - COVID Case/Death Prediction

# %% [markdown]
# ## Introduction
# Throughout this course  we have learned various methods of Machine Learning. Through using different packages such as sklearn, keras, xgboost, and  imblearning we were able to perform different techniques of learning on different datasets. In this instance today, we are training a neural network to predict the Covid-19 cases and deaths in Canada for the days of April 17, 18 and 19. It will utilize a training set of the past data and it will be tested against current data in order to come up with the perdiciton.

# %% [markdown]
# ## Packages
# The packages we will need to build these nerual networks are numpy, pandas, sklearn.preprocessing and from there we will need the MinMaxScaler, keras.models and from there we will need the sequential function, keras.layers and from there we will need LTSM, Dense, and Dropout.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM,Dense ,Dropout
from keras import callbacks

#Needed packages

# %% [markdown]
# ## Seed
# Here we are using Numpy to set a seed so that every time this code is run, the results of training the model does not vary too much. We set our future value of 3 which indicates how many variables we plan to predict and we set our past variable to 56 to indicate how many days will be used to predict the future days.

# %%
np.random.seed(17) #Set seed
future = 3 #How many predictions
past = 56  #How many past observations these predictions are based on

# %% [markdown]
# ## Training Case Data Set
# In this cell, we are going to load the dataset that we will use to make our training set using Pandas. Intially, these dataset consists of 177,143 observations and 67 different variables. The variables that are needed for the training set will be total_cases and total_deaths from Canada's observations. Due to this, the next step was to filter the dataset based on the location so that it would return only Canadian values. Then located the needed variables using iloc and tranformed the dataset using values and stored it in their respective local variables.

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv' #Link to datasaet
dataset = pd.read_csv(url,index_col=0,parse_dates=[0]) #Load dataset
dataset = dataset[dataset['location']=='Canada'] #Filter for Canada data
dataset = dataset[dataset["date"]<"2022-04-18"] #Filter for dates
dataset = dataset.fillna(0) #Replace null values with 0
training_setcase = dataset.iloc[:-past,3:4].values #Create training set of total_cases as an array
dataset.tail(3)
# Out:
# <ipython-input-66-26cb09bf479b>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset = pd.read_csv(url,index_col=0,parse_dates=[0]) #Load dataset
#               continent location        date  total_cases  new_cases  \
# iso_code
# CAN       North America   Canada  2022-04-15    3561059.0        0.0
# CAN       North America   Canada  2022-04-16    3561059.0        0.0
# CAN       North America   Canada  2022-04-17    3628005.0    66946.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# CAN                  9808.00       37977.0         0.0                43.71
# CAN                  9808.00       37977.0         0.0                43.71
# CAN                  9563.71       38301.0       324.0                46.29
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# iso_code                           ...
# CAN                      91729.61  ...          16.6                     0.0
# CAN                      91729.61  ...          16.6                     0.0
# CAN                      93454.08  ...          16.6                     0.0
#
#           hospital_beds_per_thousand  life_expectancy  \
# iso_code
# CAN                              2.5            82.43
# CAN                              2.5            82.43
# CAN                              2.5            82.43
#
#           human_development_index  population  \
# iso_code
# CAN                          0.93    38454328
# CAN                          0.93    38454328
# CAN                          0.93    38454328
#
#           excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# iso_code
# CAN                                       0.00                         0.00
# CAN                                       0.00                         0.00
# CAN                                   32052.19                         4.63
#
#           excess_mortality  excess_mortality_cumulative_per_million
# iso_code
# CAN                   0.00                                     0.00
# CAN                   0.00                                     0.00
# CAN                   3.96                                   833.51
#
# [3 rows x 66 columns]

# %% [markdown]
# ## Training Data Set Case, Ctd
# After the training sets have been made, the next step is to transform the set so that they are scaled. We used the MinMaxScaler in order to normalize the cases between 0 and 1.

# %%
sc = MinMaxScaler(feature_range=(0,1)) #create function to normalize data between 0 and 1
training_set_scaledcase = sc.fit_transform(training_setcase) # normalize the total_cases array

# %% [markdown]
# ## Training Data Set, Ctd
#
# We are now prepping are the training data by creating empty lists and a future variable that will dictate how many values the predictions will be based on and how many predictions will be made. In this case we are using 8 weeks (56 days) of data to predict the next three days of data. We then use an for loop to add these values according to the values that were inputted into the future and past variables. After this list is created we convert the list to an array by using numpy and then we reshape the array using numpy again so that it cant be training in our model.

# %%
x_traincase = [] #empty list for x train
y_traincase = [] #empty list for y train
for i in range(0,len(training_set_scaledcase)-past-future+1):
    x_traincase.append(training_set_scaledcase[i : i + past , 0])
    y_traincase.append(training_set_scaledcase[i + past : i + past + future , 0 ]) #for loop that iterates values based on how the past and future variables defined earlier
x_traincase , y_traincase = np.array(x_traincase), np.array(y_traincase)   #transform list to array
x_traincase = np.reshape(x_traincase, (x_traincase.shape[0] , x_traincase.shape[1], 1) )  #reshape dataset

# %% [markdown]
# ## Model Building for Cases
# Here is the beginning of building our model. We first started by using Sequential to develop our layered model. We decided to build layers using LTSM, which stands for Long Short-Term Memory. We are using a LTSM network after research, it "has only recently become a viable and powerful forecasting technique". (https://towardsdatascience.com/lstm-framework-for-univariate-time-series-prediction-d9e7252699e#:~:text=LSTM%20methodology%2C%20while%20introduced%20in,based%20models%20like%20LSTM%20offer) We built four input layers, three of them being LTSM and two of the LTSM layers with return sequences so that when the predictions are spitout, they are reiterated back into the model. The final input layer is a dropout with a standard value of 0.2 to help mitigate overfitting. After we've added all the layes, we compile the model using the adam optimizer and use accuracy as a metric. We then fit the model to our x and y train values alongside epochs of 100 and batch_size of 64.

# %%
regressorcase = Sequential()
regressorcase.add(LSTM(units = past, return_sequences = True, input_shape = (x_traincase.shape[1], 1)))
regressorcase.add(LSTM(units = past, return_sequences = True))
regressorcase.add(LSTM(units = past))
regressorcase.add(Dropout(0.2))
regressorcase.add(Dense(units = future))
regressorcase.compile(optimizer ="adam", loss ="mean_absolute_error",
                                             metrics =['accuracy']) #build the model with 4 input layers and one output that prints
                                             #out the number of predictions defined in the earlier code. Then compiled the model using adam optimizer, mean_absolute_error for loss and accuracy for metrics
regressorcase.fit(x_traincase, y_traincase, epochs=100,batch_size= 64) #fitted the model to x train. nad y train with 100 epochs and batch size of 64
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.2478 - loss: 0.2285
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.2789 - loss: 0.0624
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2398 - loss: 0.0396
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3336 - loss: 0.0343
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.3654 - loss: 0.0318
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3170 - loss: 0.0305
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3472 - loss: 0.0284
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.3227 - loss: 0.0323
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.3061 - loss: 0.0289
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3471 - loss: 0.0295
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.2777 - loss: 0.0305
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2600 - loss: 0.0273
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3283 - loss: 0.0271
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3364 - loss: 0.0269
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2798 - loss: 0.0265
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2424 - loss: 0.0290
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.3965 - loss: 0.0262
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.2433 - loss: 0.0293
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.3039 - loss: 0.0255
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3216 - loss: 0.0250
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2747 - loss: 0.0237
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3251 - loss: 0.0254
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2050 - loss: 0.0245
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2720 - loss: 0.0237
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3530 - loss: 0.0255
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2295 - loss: 0.0228
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.2477 - loss: 0.0231
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.3101 - loss: 0.0253
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.3635 - loss: 0.0205
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.3045 - loss: 0.0228
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3063 - loss: 0.0198
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2661 - loss: 0.0243
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2949 - loss: 0.0290
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2553 - loss: 0.0252
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3236 - loss: 0.0224
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.2313 - loss: 0.0214
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.2755 - loss: 0.0214
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3585 - loss: 0.0202
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2617 - loss: 0.0199
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2416 - loss: 0.0191
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2779 - loss: 0.0196
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.3099 - loss: 0.0192
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2985 - loss: 0.0205
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2296 - loss: 0.0206
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.2497 - loss: 0.0188
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.3141 - loss: 0.0205
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.2505 - loss: 0.0193
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3150 - loss: 0.0243
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2372 - loss: 0.0207
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2565 - loss: 0.0204
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.3115 - loss: 0.0186
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.3798 - loss: 0.0191
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.2756 - loss: 0.0191
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.2507 - loss: 0.0190
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.2584 - loss: 0.0183
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.2884 - loss: 0.0203
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2341 - loss: 0.0179
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2770 - loss: 0.0187
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2793 - loss: 0.0175
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2522 - loss: 0.0186
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2922 - loss: 0.0172
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.2434 - loss: 0.0172
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.2928 - loss: 0.0184
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2600 - loss: 0.0194
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.2617 - loss: 0.0170
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.3181 - loss: 0.0189
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.2417 - loss: 0.0176
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3034 - loss: 0.0188
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2811 - loss: 0.0182
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2740 - loss: 0.0173
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.2435 - loss: 0.0173
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.2518 - loss: 0.0177
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.2743 - loss: 0.0178
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2441 - loss: 0.0178
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2770 - loss: 0.0199
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2297 - loss: 0.0176
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2388 - loss: 0.0174
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2807 - loss: 0.0144
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.2745 - loss: 0.0167
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.2706 - loss: 0.0150
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2328 - loss: 0.0184
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3184 - loss: 0.0179
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3045 - loss: 0.0204
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3387 - loss: 0.0182
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2648 - loss: 0.0160
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.3095 - loss: 0.0166
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2579 - loss: 0.0159
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 0.3081 - loss: 0.0176
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.2797 - loss: 0.0162
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2739 - loss: 0.0163
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.3155 - loss: 0.0160
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2292 - loss: 0.0154
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2323 - loss: 0.0184
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.3241 - loss: 0.0155
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2686 - loss: 0.0166
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.2643 - loss: 0.0156
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.2979 - loss: 0.0168
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.2627 - loss: 0.0152
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2431 - loss: 0.0164
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.2671 - loss: 0.0161

# %% [markdown]
# ## Test Data Set and Prediction for Cases
#
# Our test dataset will be the last 8 weeks of data from the same dataaset we used to create our training data.
#
# The same way we reshaped the training dataset we also normalized, reshaped the testing datashape, and converted it to a numpy array. We then used the testing case on the model to predict the next days of covid cases. After we run the test dataset against the model, we need to reverse the transformation process that the dataset intially underwent in order to get the data in the form that is readible. The predictions now come out as a Numpy array.

# %%
testconfirm = dataset.iloc[-past:,3:4].values #create test dataset
testingcase = sc.transform(testconfirm.reshape(-1,1)) #trainsform and reshape the dataset the same way we did for the training set
testingcase = np.array(testingcase) #transform it into an array
testingcase = np.reshape(testingcase,(testingcase.shape[1],testingcase.shape[0],1)) #reshape the test dataset
predictedcase = regressorcase.predict(testingcase) #predict the dataset based on the testing data
predictedcase = sc.inverse_transform(predictedcase)
predictedcase = np.reshape(predictedcase,(predictedcase.shape[1],predictedcase.shape[0])) #reverse the process of normalizing the dataset
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step

# %% [markdown]
# # Process for Deaths
# Repeat the same process for the the deaths prediction as well.

# %%
training_setdeath = dataset.iloc[:-past,6:7].values
training_set_scaleddeath = sc.fit_transform(training_setdeath)
x_traindeath = []
y_traindeath = []
for i in range(0,len(training_set_scaleddeath)-past-future+1):
    x_traindeath.append(training_set_scaleddeath[i : i + past , 0])
    y_traindeath.append(training_set_scaleddeath[i + past : i + past + future , 0 ])
x_traindeath , y_traindeath = np.array(x_traindeath), np.array(y_traindeath)
x_traindeath = np.reshape(x_traindeath, (x_traindeath.shape[0] , x_traindeath.shape[1], 1) )
regressordeath = Sequential()
regressordeath.add(LSTM(units = past, return_sequences = True, input_shape = (x_traindeath.shape[1], 1)))
regressordeath.add(LSTM(units = past, return_sequences = True))
regressordeath.add(LSTM(units = past))
regressordeath.add(Dropout(0.2))
regressordeath.add(Dense(units = future))
regressordeath.compile(optimizer ="adam", loss ="mean_absolute_error",
                                             metrics =['accuracy'])
regressordeath.fit(x_traindeath, y_traindeath, epochs=100,batch_size= 64 )
testdeath = dataset.iloc[-past:,6:7].values
testingdeath = sc.transform(testdeath.reshape(-1,1))
testingdeath = np.array(testingdeath)
testingdeath = np.reshape(testingdeath,(testingdeath.shape[1],testingdeath.shape[0],1))
predicteddeath = regressordeath.predict(testingdeath)
predicteddeath = sc.inverse_transform(predicteddeath)
predicteddeath = np.reshape(predicteddeath,(predicteddeath.shape[1],predicteddeath.shape[0]))
#repeat the exact same process except with deaths instaed of cases
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.1555 - loss: 0.3739
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.5033 - loss: 0.1076
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3241 - loss: 0.0693
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.2950 - loss: 0.0548
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.2984 - loss: 0.0484
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3021 - loss: 0.0511
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.3014 - loss: 0.0461
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.3133 - loss: 0.0458
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.3269 - loss: 0.0448
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.2859 - loss: 0.0455
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3604 - loss: 0.0449
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.3332 - loss: 0.0467
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.2726 - loss: 0.0426
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.3491 - loss: 0.0443
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.2845 - loss: 0.0419
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.3090 - loss: 0.0415
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.2990 - loss: 0.0400
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.3359 - loss: 0.0382
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3454 - loss: 0.0387
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3087 - loss: 0.0411
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3205 - loss: 0.0397
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.3236 - loss: 0.0371
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.3081 - loss: 0.0365
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.2375 - loss: 0.0364
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.2868 - loss: 0.0370
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.3053 - loss: 0.0377
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.3056 - loss: 0.0336
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.2869 - loss: 0.0360
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.2898 - loss: 0.0360
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3398 - loss: 0.0369
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3018 - loss: 0.0341
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3669 - loss: 0.0359
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.3053 - loss: 0.0349
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.3180 - loss: 0.0317
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.3224 - loss: 0.0346
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3450 - loss: 0.0411
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.2585 - loss: 0.0329
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.3573 - loss: 0.0336
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.3901 - loss: 0.0352
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.3301 - loss: 0.0328
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.2907 - loss: 0.0354
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.3174 - loss: 0.0311
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.3038 - loss: 0.0299
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2756 - loss: 0.0322
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.3326 - loss: 0.0304
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.3290 - loss: 0.0308
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.2826 - loss: 0.0284
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.2749 - loss: 0.0302
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3120 - loss: 0.0307
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3501 - loss: 0.0291
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.3083 - loss: 0.0286
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.2922 - loss: 0.0295
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.3237 - loss: 0.0310
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.2842 - loss: 0.0284
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3359 - loss: 0.0323
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.2892 - loss: 0.0321
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.2962 - loss: 0.0308
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.3124 - loss: 0.0305
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.2912 - loss: 0.0273
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.3151 - loss: 0.0262
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.3120 - loss: 0.0316
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.3372 - loss: 0.0292
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.2521 - loss: 0.0262
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.3359 - loss: 0.0270
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.3093 - loss: 0.0274
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.3900 - loss: 0.0258
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.3605 - loss: 0.0287
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.2985 - loss: 0.0271
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.2960 - loss: 0.0251
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.2644 - loss: 0.0292
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.2261 - loss: 0.0253
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.2780 - loss: 0.0271
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.3369 - loss: 0.0264
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.2956 - loss: 0.0264
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.3064 - loss: 0.0275
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.2970 - loss: 0.0292
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.3193 - loss: 0.0259
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.2904 - loss: 0.0268
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.2858 - loss: 0.0244
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3381 - loss: 0.0262
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.2857 - loss: 0.0256
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3106 - loss: 0.0281
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.2464 - loss: 0.0246
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.3274 - loss: 0.0256
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.2875 - loss: 0.0249
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.2231 - loss: 0.0236
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.3569 - loss: 0.0264
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.2668 - loss: 0.0262
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3108 - loss: 0.0257
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.2857 - loss: 0.0248
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.2638 - loss: 0.0233
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.3811 - loss: 0.0251
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.2503 - loss: 0.0248
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.2692 - loss: 0.0222
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.2918 - loss: 0.0225
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.2499 - loss: 0.0215
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.2665 - loss: 0.0241
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.2538 - loss: 0.0239
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.3165 - loss: 0.0232
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.2849 - loss: 0.0234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step

# %% [markdown]
# ## Final Results
#
# We then transform these arrays into a rounded number and put them into a list. These lists are then combined and then we used pandas to develop a DataFrame to input this list. This DataFrame has the predicted values for their respective category and date.

# %%
case = (np.squeeze(predictedcase.astype(int)))
death =  (np.squeeze(predicteddeath.astype(int)))#from float to integer for both case and death array
combined = [case, death] #put case and death into a list
column_names = ['April 18', 'April 19', 'April 20'] #create column names for the DataFrame
df = pd.DataFrame(columns = column_names, index=[ 'Total Cases', 'Total Deaths'], data=combined) #turn the predictions to DataFrame
df.index.name = 'Canada' #create index name
print(df) #print final results
df.to_csv("FinalResults.csv")
# Out:
#               April 18  April 19  April 20
# Canada
# Total Cases    3735286   3737669   3741433
# Total Deaths     38569     38627     38827

# %% [markdown]
# # Reference
# https://medium.com/analytics-vidhya/weather-forecasting-with-recurrent-neural-networks-1eaa057d70c3 for guidance
